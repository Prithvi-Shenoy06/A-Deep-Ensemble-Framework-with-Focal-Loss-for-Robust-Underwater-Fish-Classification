# %%
import os
import time
import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from tqdm import tqdm
import timm
import matplotlib.pyplot as plt

# ==== Device ====
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"🔧 Using device: {device}")

# ==== Paths ====
data_dir = r"C:\Users\STUDENT\Downloads\FishDataset_Split"
save_path = "best_fish_model(swin).pth"

# ==== Transforms ====
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.3),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

test_val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# ==== Datasets and Dataloaders ====
train_dataset = datasets.ImageFolder(os.path.join(data_dir, "train"), transform=train_transform)
val_dataset = datasets.ImageFolder(os.path.join(data_dir, "val"), transform=test_val_transform)
test_dataset = datasets.ImageFolder(os.path.join(data_dir, "test"), transform=test_val_transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
val_loader   = DataLoader(val_dataset,   batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
test_loader  = DataLoader(test_dataset,  batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

class_names = train_dataset.classes
num_classes = len(class_names)
# Out:
# 🔧 Using device: cuda

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_counts = [len(os.listdir(os.path.join(data_dir, 'train', c)))
                for c in sorted(os.listdir(os.path.join(data_dir, 'train')))]

class_weights = compute_class_weight(class_weight='balanced',
                                     classes=np.arange(len(class_counts)),
                                     y=np.concatenate([[i]*count for i, count in enumerate(class_counts)]))

class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
from torch.amp import autocast, GradScaler
# Load Swin Transformer model from timm
model = timm.create_model('swin_tiny_patch4_window7_224', pretrained=True, num_classes=num_classes)
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
scaler = GradScaler()

# %%
def evaluate(model, loader):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    avg_loss = total_loss / total
    acc = 100 * correct / total
    return avg_loss, acc

# %%
from torch.amp import autocast, GradScaler

# Initialize scaler (outside the function)
scaler = GradScaler()

def train_model(model, train_loader, val_loader, epochs=50, patience=5):
    best_val_acc = 0.0
    best_epoch = 0
    early_stop_counter = 0

    train_loss_history, val_loss_history = [], []
    train_acc_history, val_acc_history = [], []

    for epoch in range(epochs):
        model.train()
        train_loss = 0
        correct = 0
        total = 0

        for inputs, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs}"):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

            # === Mixed precision training block ===
            with autocast(device_type=device.type):
                outputs = model(inputs)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            # =======================================

            train_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        avg_train_loss = train_loss / total
        train_acc = 100 * correct / total
        val_loss, val_acc = evaluate(model, val_loader)

        train_loss_history.append(avg_train_loss)
        val_loss_history.append(val_loss)
        train_acc_history.append(train_acc)
        val_acc_history.append(val_acc)

        # Save best model
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_epoch = epoch
            early_stop_counter = 0
            torch.save(model.state_dict(), "best_fish_model(swin).pth")
            print(f"✅ Saved best model at epoch {epoch+1} with Val Acc: {val_acc:.2f}%")
        else:
            early_stop_counter += 1
            print(f"⏳ No improvement for {early_stop_counter} epoch(s)")

        # Print epoch results
        print(f"Epoch {epoch+1}:")
        print(f"  Train Loss: {avg_train_loss:.4f}, Train Acc: {train_acc:.2f}%")
        print(f"  Val   Loss: {val_loss:.4f}, Val   Acc: {val_acc:.2f}%")

        # Stop if no improvement
        if early_stop_counter >= patience:
            print(f"🛑 Early stopping triggered after {patience} epochs without improvement.")
            break

    print(f"\n🏁 Best Val Acc: {best_val_acc:.2f}% at epoch {best_epoch+1}")
    return train_loss_history, train_acc_history, val_loss_history, val_acc_history

# %%
import time
import pickle

# Start timing ⏱️
start_time = time.time()

# Call the training function
train_loss, train_acc, val_loss, val_acc = train_model(model, train_loader, val_loader, epochs=250)

# End timing ⏱️
end_time = time.time()
elapsed = end_time - start_time

# Save history to pickle
history = {
    'train_loss': train_loss,
    'train_acc': train_acc,
    'val_loss': val_loss,
    'val_acc': val_acc
}

with open("training_history(swin).pkl", "wb") as f:
    pickle.dump(history, f)

print(f"✅ History saved to training_history(new).pkl")
print(f"🕒 Total training time: {elapsed:.2f} seconds ({elapsed/60:.2f} minutes)")
# Out:
# Epoch 1/250: 100%|██████████| 195/195 [00:38<00:00,  5.10it/s]
# ✅ Saved best model at epoch 1 with Val Acc: 89.29%
# Epoch 1:
#   Train Loss: 1.1190, Train Acc: 70.16%
#   Val   Loss: 0.3689, Val   Acc: 89.29%
# Epoch 2/250: 100%|██████████| 195/195 [00:37<00:00,  5.25it/s]
# ✅ Saved best model at epoch 2 with Val Acc: 91.49%
# Epoch 2:
#   Train Loss: 0.3093, Train Acc: 91.00%
#   Val   Loss: 0.2989, Val   Acc: 91.49%
# Epoch 3/250: 100%|██████████| 195/195 [00:37<00:00,  5.22it/s]
# ⏳ No improvement for 1 epoch(s)
# Epoch 3:
#   Train Loss: 0.1549, Train Acc: 95.85%
#   Val   Loss: 0.3805, Val   Acc: 89.29%
# Epoch 4/250: 100%|██████████| 195/195 [00:37<00:00,  5.27it/s]
# ✅ Saved best model at epoch 4 with Val Acc: 92.78%
# Epoch 4:
#   Train Loss: 0.1280, Train Acc: 96.38%
#   Val   Loss: 0.3082, Val   Acc: 92.78%
# Epoch 5/250: 100%|██████████| 195/195 [00:37<00:00,  5.22it/s]
# ⏳ No improvement for 1 epoch(s)
# Epoch 5:
#   Train Loss: 0.0966, Train Acc: 96.80%
#   Val   Loss: 0.2939, Val   Acc: 92.17%
# Epoch 6/250: 100%|██████████| 195/195 [00:36<00:00,  5.28it/s]
# ✅ Saved best model at epoch 6 with Val Acc: 93.84%
# Epoch 6:
#   Train Loss: 0.0950, Train Acc: 97.38%
#   Val   Loss: 0.2257, Val   Acc: 93.84%
# Epoch 7/250: 100%|██████████| 195/195 [00:37<00:00,  5.25it/s]
# ⏳ No improvement for 1 epoch(s)
# Epoch 7:
#   Train Loss: 0.0606, Train Acc: 98.36%
#   Val   Loss: 0.2603, Val   Acc: 93.77%
# Epoch 8/250: 100%|██████████| 195/195 [00:37<00:00,  5.23it/s]
# ⏳ No improvement for 2 epoch(s)
# Epoch 8:
#   Train Loss: 0.0862, Train Acc: 97.25%
#   Val   Loss: 0.3787, Val   Acc: 90.20%
# Epoch 9/250: 100%|██████████| 195/195 [00:37<00:00,  5.20it/s]
# ⏳ No improvement for 3 epoch(s)
# Epoch 9:
#   Train Loss: 0.0777, Train Acc: 97.86%
#   Val   Loss: 0.3545, Val   Acc: 91.34%
# Epoch 10/250: 100%|██████████| 195/195 [00:37<00:00,  5.27it/s]
# ⏳ No improvement for 4 epoch(s)
# Epoch 10:
#   Train Loss: 0.0897, Train Acc: 97.18%
#   Val   Loss: 0.3298, Val   Acc: 92.55%
# Epoch 11/250: 100%|██████████| 195/195 [00:37<00:00,  5.24it/s]
# ⏳ No improvement for 5 epoch(s)
# Epoch 11:
#   Train Loss: 0.0666, Train Acc: 98.08%
#   Val   Loss: 0.3017, Val   Acc: 92.63%
# 🛑 Early stopping triggered after 5 epochs without improvement.
#
# 🏁 Best Val Acc: 93.84% at epoch 6
# ✅ History saved to training_history(new).pkl
# 🕒 Total training time: 553.43 seconds (9.22 minutes)

# %%
with open("training_history(swin).pkl", "rb") as f:
    history = pickle.load(f)

print(history.keys())
# Out:
# dict_keys(['train_loss', 'train_acc', 'val_loss', 'val_acc'])

# %%
criterion = torch.nn.CrossEntropyLoss()

# %%
import os
import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import timm
from tqdm import tqdm
import matplotlib.pyplot as plt

# === Paths ===
data_dir = r"C:\Users\STUDENT\Downloads\FishDataset_Split"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === Transforms ===
test_val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# === Load datasets from split folders ===
train_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "train"), transform=test_val_transform)
val_dataset   = datasets.ImageFolder(root=os.path.join(data_dir, "val"), transform=test_val_transform)
test_dataset  = datasets.ImageFolder(root=os.path.join(data_dir, "test"), transform=test_val_transform)
num_classes = len(train_dataset.classes)

# === Dataloaders ===
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=32, shuffle=False)

# === Model ===
# === Model ===
model = timm.create_model('swin_tiny_patch4_window7_224', pretrained=False)
model.head.fc = nn.Linear(model.head.fc.in_features, num_classes)  # ✅ Replace classification head
model.load_state_dict(torch.load("best_fish_model(swin).pth"))  # ✅ Make sure this path is correct
model = model.to(device)
model.eval()



print("✅ Model restored and ready for testing.")
# Out:
# ✅ Model restored and ready for testing.

# %%
# Load best model
model.load_state_dict(torch.load("best_fish_model(swin).pth"))
model.eval()

# Evaluate on validation set
val_loss_final, val_acc_final = evaluate(model, val_loader)

# Evaluate on test set
test_loss, test_acc = evaluate(model, test_loader)

# Print results
print(f" Final Validation Accuracy: {val_acc_final:.2f}%, Validation Loss: {val_loss_final:.4f}")
print(f" Final Test Accuracy:      {test_acc:.2f}%, Test Loss:      {test_loss:.4f}")
# Out:
#  Final Validation Accuracy: 93.84%, Validation Loss: 0.2253
#  Final Test Accuracy:      92.39%, Test Loss:      0.2898

# %%
import os
import torch
import timm
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torchvision import transforms
import matplotlib.pyplot as plt

# === Paths and Device ===
folder_path = r"C:\Users\STUDENT\Downloads\test_images"
model_path = "best_fish_model(swin).pth"
class_names = sorted(os.listdir(r"C:\Users\STUDENT\Downloads\FishDataset_Split/Train"))
device = torch.device('cpu')  # Or use 'cuda' if available

# === Image Transform ===
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Required for convnext_tiny
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# === Load convnext_tiny Model ===
model = timm.create_model('swin_tiny_patch4_window7_224', pretrained=False)
model.head.fc = nn.Linear(model.head.fc.in_features, num_classes)  # ✅ Replace classification head
model.load_state_dict(torch.load("best_fish_model(swin).pth"))  # ✅ Make sure this path is correct
model = model.to(device)
model.eval()

print("✅swin_tiny model loaded and ready for inference.")

# === Run Inference on Images ===
for filename in os.listdir(folder_path):
    if not filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        continue

    try:
        img_path = os.path.join(folder_path, filename)
        image = Image.open(img_path).convert('RGB')
        input_tensor = transform(image).unsqueeze(0).to(device)

        with torch.no_grad():
            output = model(input_tensor)
            probabilities = F.softmax(output, dim=1)
            prob, pred = torch.max(probabilities, 1)

        predicted_class = class_names[pred.item()]
        confidence = prob.item() * 100

        print(f"📷 {filename} →  Predicted: {predicted_class} ({confidence:.2f}%)")

        # Optional: Visualize prediction
        # plt.imshow(image)
        # plt.title(f"{filename}\nPredicted: {predicted_class} ({confidence:.2f}%)")
        # plt.axis('off')
        # plt.show()
        # plt.close()

    except Exception as e:
        print(f"⚠️ Error processing {filename}: {e}")
        continue
# Out:
# ✅swin_tiny model loaded and ready for inference.
# 📷 1.jpg →  Predicted: Bangus (100.00%)
# 📷 2.jpg →  Predicted: Bangus (100.00%)
# 📷 4.jpg →  Predicted: Gold Fish (100.00%)
# 📷 5.jpg →  Predicted: Freshwater Eel (83.96%)
# 📷 6.jpg →  Predicted: Gourami (100.00%)
# 📷 7.jpg →  Predicted: Gold Fish (100.00%)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, confusion_matrix
import numpy as np
import torch

def compute_metrics(model, loader, class_names=None):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # === Compute metrics ===
    precision = precision_score(all_labels, all_preds, average='weighted')
    recall    = recall_score(all_labels, all_preds, average='weighted')
    f1        = f1_score(all_labels, all_preds, average='weighted')

    # === Print ===
    print(f"🔍 Precision: {precision:.4f}")
    print(f"🔁 Recall:    {recall:.4f}")
    print(f"⭐ F1 Score:  {f1:.4f}")

    if class_names:
        print("\n📋 Classification Report:")
        print(classification_report(all_labels, all_preds, target_names=class_names))

    # Optional: Confusion Matrix

    return precision, recall, f1

# %%
# 📦 Call the function to trigger execution
class_names = test_dataset.classes  # or train_dataset.classes if needed
precision, recall, f1 = compute_metrics(model, test_loader, class_names)
# Out:
# 🔍 Precision: 0.9256
# 🔁 Recall:    0.9239
# ⭐ F1 Score:  0.9236
#
# 📋 Classification Report:
#                        precision    recall  f1-score   support
#
#                Bangus       0.69      0.89      0.77        27
#         Big Head Carp       0.81      0.78      0.79        32
#    Black Spotted Barb       0.94      1.00      0.97        31
#               Catfish       0.90      0.92      0.91        50
#        Climbing Perch       0.87      0.83      0.85        24
#  Fourfinger Threadfin       0.96      0.83      0.89        30
#        Freshwater Eel       0.95      0.93      0.94        42
#        Glass Perchlet       0.91      0.97      0.94        61
#                  Goby       0.91      0.92      0.91        93
#             Gold Fish       0.97      1.00      0.99        34
#               Gourami       0.96      0.98      0.97        48
#            Grass Carp       0.97      0.97      0.97       190
#  Green Spotted Puffer       0.95      1.00      0.97        18
#           Indian Carp       0.93      1.00      0.96        41
#   Indo-Pacific Tarpon       0.96      0.93      0.95        29
#         Jaguar Gapote       0.95      1.00      0.97        36
#          Janitor Fish       0.94      0.98      0.96        45
#             Knifefish       0.98      0.96      0.97        50
# Long-Snouted Pipefish       1.00      0.97      0.99        40
#         Mosquito Fish       0.95      0.92      0.93        38
#               Mudfish       0.67      0.62      0.64        29
#                Mullet       0.86      0.86      0.86        28
#             Pangasius       0.96      0.83      0.89        30
#                 Perch       0.93      0.93      0.93        46
#             Scat Fish       1.00      1.00      1.00        22
#           Silver Barb       0.98      0.90      0.94        50
#           Silver Carp       0.95      1.00      0.97        38
#          Silver Perch       0.89      0.91      0.90        43
#             Snakehead       0.78      0.78      0.78        37
#            Tenpounder       0.97      0.74      0.84        39
#               Tilapia       0.91      0.93      0.92        46
#
#              accuracy                           0.92      1367
#             macro avg       0.92      0.91      0.91      1367
#          weighted avg       0.93      0.92      0.92      1367

# %%
import os
import torch
import timm
import pickle
import numpy as np
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import StratifiedKFold
from tqdm import tqdm

# ==== Config ====
data_dir = r"C:\Users\STUDENT\Downloads\FishDataset_Split"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
k = 5
epochs = 10
batch_size = 32
learning_rate = 1e-4

# ==== Transforms ====
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(0.2, 0.2, 0.3),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])
val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# ==== Dataset & Labels ====
full_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "train"), transform=train_transform)
labels = [sample[1] for sample in full_dataset]
num_classes = len(full_dataset.classes)

# ==== Train Function ====
def train_model(model, train_loader, val_loader, criterion, optimizer, epochs):
    train_loss_hist, val_loss_hist = [], []
    train_acc_hist, val_acc_hist = [], []

    for epoch in range(epochs):
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            correct += (outputs.argmax(1) == labels).sum().item()
            total += labels.size(0)
        train_loss_hist.append(running_loss / total)
        train_acc_hist.append(correct / total)

        # Validation
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                val_correct += (outputs.argmax(1) == labels).sum().item()
                val_total += labels.size(0)
        val_loss_hist.append(val_loss / val_total)
        val_acc_hist.append(val_correct / val_total)

        print(f"📚 Epoch {epoch+1}/{epochs}: Train Acc={train_acc_hist[-1]:.4f}, Val Acc={val_acc_hist[-1]:.4f}")

    return train_loss_hist, train_acc_hist, val_loss_hist, val_acc_hist

# ==== Cross-Validation ====
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)
cv_results = []

for fold, (train_idx, val_idx) in enumerate(skf.split(np.zeros(len(labels)), labels)):
    print(f"\n🔁 Fold {fold+1}/{k}")
    train_subset = Subset(full_dataset, train_idx)
    val_subset = Subset(full_dataset, val_idx)
    train_subset.dataset.transform = train_transform
    val_subset.dataset.transform = val_transform

    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False, num_workers=2)

    model = timm.create_model('swin_tiny_patch4_window7_224', pretrained=True, num_classes=num_classes)
    model = model.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    train_loss, train_acc, val_loss, val_acc = train_model(model, train_loader, val_loader,
                                                           criterion, optimizer, epochs)

    fold_result = {
        "fold": fold + 1,
        "train_acc": train_acc[-1],
        "val_acc": val_acc[-1],
        "train_loss": train_loss[-1],
        "val_loss": val_loss[-1],
        "train_acc_hist": train_acc,
        "val_acc_hist": val_acc,
        "train_loss_hist": train_loss,
        "val_loss_hist": val_loss
    }
    cv_results.append(fold_result)

    torch.save(model.state_dict(), f"swin_fold{fold+1}.pth")
    print(f"💾 Saved model for Fold {fold+1}")

# ==== Save Cross-Validation History ====
with open("swin_crossval_history.pkl", "wb") as f:
    pickle.dump(cv_results, f)

# ==== Summary ====
print("\n📊 Cross-Validation Summary:")
for r in cv_results:
    print(f"Fold {r['fold']}: Val Acc = {r['val_acc']:.4f}, Val Loss = {r['val_loss']:.4f}")
# Out:
# 🔁 Fold 1/5
# 📚 Epoch 1/10: Train Acc=0.7077, Val Acc=0.8882
# 📚 Epoch 2/10: Train Acc=0.9463, Val Acc=0.9155
# 📚 Epoch 3/10: Train Acc=0.9835, Val Acc=0.9300
# 📚 Epoch 4/10: Train Acc=0.9833, Val Acc=0.9316
# 📚 Epoch 5/10: Train Acc=0.9857, Val Acc=0.9276
# 📚 Epoch 6/10: Train Acc=0.9889, Val Acc=0.9220
# 📚 Epoch 7/10: Train Acc=0.9976, Val Acc=0.9389
# 📚 Epoch 8/10: Train Acc=0.9958, Val Acc=0.9212
# 📚 Epoch 9/10: Train Acc=0.9853, Val Acc=0.9187
# 📚 Epoch 10/10: Train Acc=0.9837, Val Acc=0.9195
# 💾 Saved model for Fold 1
#
# 🔁 Fold 2/5
# 📚 Epoch 1/10: Train Acc=0.7093, Val Acc=0.8850
# 📚 Epoch 2/10: Train Acc=0.9423, Val Acc=0.8922
# 📚 Epoch 3/10: Train Acc=0.9821, Val Acc=0.9059
# 📚 Epoch 4/10: Train Acc=0.9871, Val Acc=0.9155
# 📚 Epoch 5/10: Train Acc=0.9940, Val Acc=0.9107
# 📚 Epoch 6/10: Train Acc=0.9946, Val Acc=0.9083
# 📚 Epoch 7/10: Train Acc=0.9964, Val Acc=0.9195
# 📚 Epoch 8/10: Train Acc=0.9817, Val Acc=0.8681
# 📚 Epoch 9/10: Train Acc=0.9781, Val Acc=0.8930
# 📚 Epoch 10/10: Train Acc=0.9859, Val Acc=0.9220
# 💾 Saved model for Fold 2
#
# 🔁 Fold 3/5
# 📚 Epoch 1/10: Train Acc=0.6948, Val Acc=0.8842
# 📚 Epoch 2/10: Train Acc=0.9390, Val Acc=0.9268
# 📚 Epoch 3/10: Train Acc=0.9799, Val Acc=0.9284
# 📚 Epoch 4/10: Train Acc=0.9889, Val Acc=0.9244
# 📚 Epoch 5/10: Train Acc=0.9942, Val Acc=0.9405
# 📚 Epoch 6/10: Train Acc=0.9940, Val Acc=0.9284
# 📚 Epoch 7/10: Train Acc=0.9881, Val Acc=0.9091
# 📚 Epoch 8/10: Train Acc=0.9819, Val Acc=0.9075
# 📚 Epoch 9/10: Train Acc=0.9835, Val Acc=0.9147
# 📚 Epoch 10/10: Train Acc=0.9839, Val Acc=0.9204
# 💾 Saved model for Fold 3
#
# 🔁 Fold 4/5
# 📚 Epoch 1/10: Train Acc=0.7137, Val Acc=0.8713
# 📚 Epoch 2/10: Train Acc=0.9479, Val Acc=0.9067
# 📚 Epoch 3/10: Train Acc=0.9759, Val Acc=0.9260
# 📚 Epoch 4/10: Train Acc=0.9869, Val Acc=0.9260
# 📚 Epoch 5/10: Train Acc=0.9913, Val Acc=0.9308
# 📚 Epoch 6/10: Train Acc=0.9940, Val Acc=0.9179
# 📚 Epoch 7/10: Train Acc=0.9839, Val Acc=0.9115
# 📚 Epoch 8/10: Train Acc=0.9877, Val Acc=0.9043
# 📚 Epoch 9/10: Train Acc=0.9865, Val Acc=0.9204
# 📚 Epoch 10/10: Train Acc=0.9863, Val Acc=0.9268
# 💾 Saved model for Fold 4
#
# 🔁 Fold 5/5
# 📚 Epoch 1/10: Train Acc=0.7094, Val Acc=0.9122
# 📚 Epoch 2/10: Train Acc=0.9431, Val Acc=0.9018
# 📚 Epoch 3/10: Train Acc=0.9799, Val Acc=0.9171
# 📚 Epoch 4/10: Train Acc=0.9905, Val Acc=0.9348
# 📚 Epoch 5/10: Train Acc=0.9928, Val Acc=0.9283
# 📚 Epoch 6/10: Train Acc=0.9889, Val Acc=0.9187
# 📚 Epoch 7/10: Train Acc=0.9781, Val Acc=0.9308
# 📚 Epoch 8/10: Train Acc=0.9825, Val Acc=0.9195
# 📚 Epoch 9/10: Train Acc=0.9952, Val Acc=0.9235
# 📚 Epoch 10/10: Train Acc=0.9912, Val Acc=0.9179
# 💾 Saved model for Fold 5
#
# 📊 Cross-Validation Summary:
# Fold 1: Val Acc = 0.9195, Val Loss = 0.3610
# Fold 2: Val Acc = 0.9220, Val Loss = 0.3416
# Fold 3: Val Acc = 0.9204, Val Loss = 0.3558
# Fold 4: Val Acc = 0.9268, Val Loss = 0.3230
# Fold 5: Val Acc = 0.9179, Val Loss = 0.3552

# %%
# Same imports, transforms, dataset, train_model(), etc. from previous block
# Just rerun this tuning block separately after that setup

learning_rates = [1e-4, 5e-5, 1e-5]

batch_sizes = [32, 64]
tuning_results = []

for lr in learning_rates:
    for bs in batch_sizes:
        print(f"\n🔧 Tuning for LR={lr}, Batch Size={bs}")
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
        fold_metrics = []

        for fold, (train_idx, val_idx) in enumerate(skf.split(np.zeros(len(labels)), labels)):
            print(f"   🔁 Fold {fold+1}/5")

            train_subset = Subset(full_dataset, train_idx)
            val_subset = Subset(full_dataset, val_idx)
            train_subset.dataset.transform = train_transform
            val_subset.dataset.transform = val_transform

            train_loader = DataLoader(train_subset, batch_size=bs, shuffle=True, num_workers=2)
            val_loader = DataLoader(val_subset, batch_size=bs, shuffle=False, num_workers=2)

            model = timm.create_model('swin_tiny_patch4_window7_224', pretrained=True, num_classes=num_classes)
            model = model.to(device)

            optimizer = optim.Adam(model.parameters(), lr=lr)
            criterion = nn.CrossEntropyLoss()

            _, _, _, val_acc = train_model(model, train_loader, val_loader, criterion, optimizer, epochs=10)

            fold_metrics.append(val_acc[-1])

        avg_val_acc = np.mean(fold_metrics)
        tuning_results.append({"lr": lr, "bs": bs, "avg_val_acc": avg_val_acc})
        print(f"✅ LR={lr}, BS={bs} → Avg Val Acc: {avg_val_acc:.4f}")

# Save tuning results
with open("swin_tuning_results.pkl", "wb") as f:
    pickle.dump(tuning_results, f)

# Print best hyperparameter combination
best = max(tuning_results, key=lambda x: x["avg_val_acc"])
print(f"\n🏆 Best Config → LR={best['lr']}, BS={best['bs']} with Val Acc={best['avg_val_acc']:.4f}")
# Out:
# 🔧 Tuning for LR=0.0001, Batch Size=32
#    🔁 Fold 1/5
# 📚 Epoch 1/10: Train Acc=0.7053, Val Acc=0.9010
# 📚 Epoch 2/10: Train Acc=0.9431, Val Acc=0.9171
# 📚 Epoch 3/10: Train Acc=0.9805, Val Acc=0.9332
# 📚 Epoch 4/10: Train Acc=0.9895, Val Acc=0.9252
# 📚 Epoch 5/10: Train Acc=0.9940, Val Acc=0.9364
# 📚 Epoch 6/10: Train Acc=0.9857, Val Acc=0.9252
# 📚 Epoch 7/10: Train Acc=0.9875, Val Acc=0.9260
# 📚 Epoch 8/10: Train Acc=0.9795, Val Acc=0.8858
# 📚 Epoch 9/10: Train Acc=0.9827, Val Acc=0.9155
# 📚 Epoch 10/10: Train Acc=0.9932, Val Acc=0.9364
#    🔁 Fold 2/5
# 📚 Epoch 1/10: Train Acc=0.7009, Val Acc=0.8833
# 📚 Epoch 2/10: Train Acc=0.9419, Val Acc=0.9204
# 📚 Epoch 3/10: Train Acc=0.9799, Val Acc=0.9115
# 📚 Epoch 4/10: Train Acc=0.9911, Val Acc=0.9083
# 📚 Epoch 5/10: Train Acc=0.9883, Val Acc=0.9010
# 📚 Epoch 6/10: Train Acc=0.9889, Val Acc=0.8898
# 📚 Epoch 7/10: Train Acc=0.9839, Val Acc=0.8930
# 📚 Epoch 8/10: Train Acc=0.9841, Val Acc=0.8938
# 📚 Epoch 9/10: Train Acc=0.9895, Val Acc=0.9075
# 📚 Epoch 10/10: Train Acc=0.9924, Val Acc=0.9035
#    🔁 Fold 3/5
# 📚 Epoch 1/10: Train Acc=0.7025, Val Acc=0.8954
# 📚 Epoch 2/10: Train Acc=0.9390, Val Acc=0.9147
# 📚 Epoch 3/10: Train Acc=0.9801, Val Acc=0.9212
# 📚 Epoch 4/10: Train Acc=0.9936, Val Acc=0.9308
# 📚 Epoch 5/10: Train Acc=0.9944, Val Acc=0.9260
# 📚 Epoch 6/10: Train Acc=0.9861, Val Acc=0.9187
# 📚 Epoch 7/10: Train Acc=0.9807, Val Acc=0.9107
# 📚 Epoch 8/10: Train Acc=0.9865, Val Acc=0.9260
# 📚 Epoch 9/10: Train Acc=0.9887, Val Acc=0.9107
# 📚 Epoch 10/10: Train Acc=0.9885, Val Acc=0.9228
#    🔁 Fold 4/5
# 📚 Epoch 1/10: Train Acc=0.7151, Val Acc=0.8946
# 📚 Epoch 2/10: Train Acc=0.9443, Val Acc=0.8842
# 📚 Epoch 3/10: Train Acc=0.9757, Val Acc=0.9236
# 📚 Epoch 4/10: Train Acc=0.9920, Val Acc=0.9340
# 📚 Epoch 5/10: Train Acc=0.9942, Val Acc=0.9397
# 📚 Epoch 6/10: Train Acc=0.9960, Val Acc=0.9332
# 📚 Epoch 7/10: Train Acc=0.9779, Val Acc=0.8946
# 📚 Epoch 8/10: Train Acc=0.9799, Val Acc=0.9131
# 📚 Epoch 9/10: Train Acc=0.9781, Val Acc=0.9131
# 📚 Epoch 10/10: Train Acc=0.9930, Val Acc=0.9252
#    🔁 Fold 5/5
# 📚 Epoch 1/10: Train Acc=0.7021, Val Acc=0.8720
# 📚 Epoch 2/10: Train Acc=0.9419, Val Acc=0.9098
# 📚 Epoch 3/10: Train Acc=0.9817, Val Acc=0.9211
# 📚 Epoch 4/10: Train Acc=0.9934, Val Acc=0.9324
# 📚 Epoch 5/10: Train Acc=0.9891, Val Acc=0.9211
# 📚 Epoch 6/10: Train Acc=0.9831, Val Acc=0.9074
# 📚 Epoch 7/10: Train Acc=0.9841, Val Acc=0.9130
# 📚 Epoch 8/10: Train Acc=0.9934, Val Acc=0.9251
# 📚 Epoch 9/10: Train Acc=0.9942, Val Acc=0.9300
# 📚 Epoch 10/10: Train Acc=0.9946, Val Acc=0.9211
# ✅ LR=0.0001, BS=32 → Avg Val Acc: 0.9218
#
# 🔧 Tuning for LR=0.0001, Batch Size=64
#    🔁 Fold 1/5
# 📚 Epoch 1/10: Train Acc=0.6341, Val Acc=0.8793
# 📚 Epoch 2/10: Train Acc=0.9366, Val Acc=0.9324
# 📚 Epoch 3/10: Train Acc=0.9831, Val Acc=0.9244
# 📚 Epoch 4/10: Train Acc=0.9936, Val Acc=0.9268
# 📚 Epoch 5/10: Train Acc=0.9960, Val Acc=0.9413
# 📚 Epoch 6/10: Train Acc=0.9986, Val Acc=0.9389
# 📚 Epoch 7/10: Train Acc=0.9986, Val Acc=0.9389
# 📚 Epoch 8/10: Train Acc=0.9952, Val Acc=0.9284
# 📚 Epoch 9/10: Train Acc=0.9907, Val Acc=0.9252
# 📚 Epoch 10/10: Train Acc=0.9853, Val Acc=0.9107
#    🔁 Fold 2/5
# 📚 Epoch 1/10: Train Acc=0.6578, Val Acc=0.8833
# 📚 Epoch 2/10: Train Acc=0.9360, Val Acc=0.9123
# 📚 Epoch 3/10: Train Acc=0.9769, Val Acc=0.9268
# 📚 Epoch 4/10: Train Acc=0.9920, Val Acc=0.9324
# 📚 Epoch 5/10: Train Acc=0.9922, Val Acc=0.9244
# 📚 Epoch 6/10: Train Acc=0.9960, Val Acc=0.9316
# 📚 Epoch 7/10: Train Acc=0.9932, Val Acc=0.9236
# 📚 Epoch 8/10: Train Acc=0.9942, Val Acc=0.9179
# 📚 Epoch 9/10: Train Acc=0.9918, Val Acc=0.9260
# 📚 Epoch 10/10: Train Acc=0.9970, Val Acc=0.9252
#    🔁 Fold 3/5
# 📚 Epoch 1/10: Train Acc=0.6544, Val Acc=0.9075
# 📚 Epoch 2/10: Train Acc=0.9338, Val Acc=0.9292
# 📚 Epoch 3/10: Train Acc=0.9823, Val Acc=0.9372
# 📚 Epoch 4/10: Train Acc=0.9918, Val Acc=0.9316
# 📚 Epoch 5/10: Train Acc=0.9974, Val Acc=0.9421
# 📚 Epoch 6/10: Train Acc=0.9952, Val Acc=0.9372
# 📚 Epoch 7/10: Train Acc=0.9962, Val Acc=0.9244
# 📚 Epoch 8/10: Train Acc=0.9913, Val Acc=0.9300
# 📚 Epoch 9/10: Train Acc=0.9928, Val Acc=0.9035
# 📚 Epoch 10/10: Train Acc=0.9950, Val Acc=0.9292
#    🔁 Fold 4/5
# 📚 Epoch 1/10: Train Acc=0.6208, Val Acc=0.8906
# 📚 Epoch 2/10: Train Acc=0.9318, Val Acc=0.9139
# 📚 Epoch 3/10: Train Acc=0.9793, Val Acc=0.9276
# 📚 Epoch 4/10: Train Acc=0.9911, Val Acc=0.9284
# 📚 Epoch 5/10: Train Acc=0.9956, Val Acc=0.9332
# 📚 Epoch 6/10: Train Acc=0.9972, Val Acc=0.9348
# 📚 Epoch 7/10: Train Acc=0.9980, Val Acc=0.9340
# 📚 Epoch 8/10: Train Acc=0.9992, Val Acc=0.9308
# 📚 Epoch 9/10: Train Acc=0.9986, Val Acc=0.9252
# 📚 Epoch 10/10: Train Acc=0.9978, Val Acc=0.9316
#    🔁 Fold 5/5
# 📚 Epoch 1/10: Train Acc=0.6476, Val Acc=0.8760
# 📚 Epoch 2/10: Train Acc=0.9360, Val Acc=0.9106
# 📚 Epoch 3/10: Train Acc=0.9799, Val Acc=0.9364
# 📚 Epoch 4/10: Train Acc=0.9934, Val Acc=0.9356
# 📚 Epoch 5/10: Train Acc=0.9976, Val Acc=0.9235
# 📚 Epoch 6/10: Train Acc=0.9962, Val Acc=0.9356
# 📚 Epoch 7/10: Train Acc=0.9984, Val Acc=0.9372
# 📚 Epoch 8/10: Train Acc=0.9980, Val Acc=0.9259
# 📚 Epoch 9/10: Train Acc=0.9948, Val Acc=0.9179
# 📚 Epoch 10/10: Train Acc=0.9905, Val Acc=0.9098
# ✅ LR=0.0001, BS=64 → Avg Val Acc: 0.9213
#
# 🔧 Tuning for LR=5e-05, Batch Size=32
#    🔁 Fold 1/5
# 📚 Epoch 1/10: Train Acc=0.6427, Val Acc=0.8898
# 📚 Epoch 2/10: Train Acc=0.9296, Val Acc=0.9187
# 📚 Epoch 3/10: Train Acc=0.9757, Val Acc=0.9212
# 📚 Epoch 4/10: Train Acc=0.9922, Val Acc=0.9348
# 📚 Epoch 5/10: Train Acc=0.9944, Val Acc=0.9421
# 📚 Epoch 6/10: Train Acc=0.9974, Val Acc=0.9381
# 📚 Epoch 7/10: Train Acc=0.9968, Val Acc=0.9445
# 📚 Epoch 8/10: Train Acc=0.9956, Val Acc=0.9340
# 📚 Epoch 9/10: Train Acc=0.9920, Val Acc=0.9316
# 📚 Epoch 10/10: Train Acc=0.9976, Val Acc=0.9340
#    🔁 Fold 2/5
# 📚 Epoch 1/10: Train Acc=0.6552, Val Acc=0.8769
# 📚 Epoch 2/10: Train Acc=0.9366, Val Acc=0.9067
# 📚 Epoch 3/10: Train Acc=0.9765, Val Acc=0.9091
# 📚 Epoch 4/10: Train Acc=0.9905, Val Acc=0.9171
# 📚 Epoch 5/10: Train Acc=0.9958, Val Acc=0.9260
# 📚 Epoch 6/10: Train Acc=0.9976, Val Acc=0.9348
# 📚 Epoch 7/10: Train Acc=0.9986, Val Acc=0.9276
# 📚 Epoch 8/10: Train Acc=0.9966, Val Acc=0.9204
# 📚 Epoch 9/10: Train Acc=0.9922, Val Acc=0.9276
# 📚 Epoch 10/10: Train Acc=0.9924, Val Acc=0.9212
#    🔁 Fold 3/5
# 📚 Epoch 1/10: Train Acc=0.6417, Val Acc=0.8817
# 📚 Epoch 2/10: Train Acc=0.9364, Val Acc=0.9147
# 📚 Epoch 3/10: Train Acc=0.9791, Val Acc=0.9300
# 📚 Epoch 4/10: Train Acc=0.9907, Val Acc=0.9284
# 📚 Epoch 5/10: Train Acc=0.9934, Val Acc=0.9397
# 📚 Epoch 6/10: Train Acc=0.9934, Val Acc=0.9364
# 📚 Epoch 7/10: Train Acc=0.9968, Val Acc=0.9107
# 📚 Epoch 8/10: Train Acc=0.9936, Val Acc=0.9284
# 📚 Epoch 9/10: Train Acc=0.9950, Val Acc=0.9123
# 📚 Epoch 10/10: Train Acc=0.9924, Val Acc=0.9340
#    🔁 Fold 4/5
# 📚 Epoch 1/10: Train Acc=0.6365, Val Acc=0.8962
# 📚 Epoch 2/10: Train Acc=0.9296, Val Acc=0.9147
# 📚 Epoch 3/10: Train Acc=0.9775, Val Acc=0.9324
# 📚 Epoch 4/10: Train Acc=0.9883, Val Acc=0.9212
# 📚 Epoch 5/10: Train Acc=0.9940, Val Acc=0.9284
# 📚 Epoch 6/10: Train Acc=0.9944, Val Acc=0.9316
# 📚 Epoch 7/10: Train Acc=0.9938, Val Acc=0.9397
# 📚 Epoch 8/10: Train Acc=0.9970, Val Acc=0.9405
# 📚 Epoch 9/10: Train Acc=0.9974, Val Acc=0.9364
# 📚 Epoch 10/10: Train Acc=0.9950, Val Acc=0.9228
#    🔁 Fold 5/5
# 📚 Epoch 1/10: Train Acc=0.6329, Val Acc=0.9010
# 📚 Epoch 2/10: Train Acc=0.9306, Val Acc=0.9275
# 📚 Epoch 3/10: Train Acc=0.9803, Val Acc=0.9179
# 📚 Epoch 4/10: Train Acc=0.9905, Val Acc=0.9356
# 📚 Epoch 5/10: Train Acc=0.9942, Val Acc=0.9308
# 📚 Epoch 6/10: Train Acc=0.9912, Val Acc=0.9348
# 📚 Epoch 7/10: Train Acc=0.9964, Val Acc=0.9348
# 📚 Epoch 8/10: Train Acc=0.9968, Val Acc=0.9436
# 📚 Epoch 9/10: Train Acc=0.9986, Val Acc=0.9372
# 📚 Epoch 10/10: Train Acc=0.9936, Val Acc=0.9356
# ✅ LR=5e-05, BS=32 → Avg Val Acc: 0.9295
#
# 🔧 Tuning for LR=5e-05, Batch Size=64
#    🔁 Fold 1/5
# 📚 Epoch 1/10: Train Acc=0.5584, Val Acc=0.8592
# 📚 Epoch 2/10: Train Acc=0.9067, Val Acc=0.9171
# 📚 Epoch 3/10: Train Acc=0.9680, Val Acc=0.9316
# 📚 Epoch 4/10: Train Acc=0.9875, Val Acc=0.9260
# 📚 Epoch 5/10: Train Acc=0.9944, Val Acc=0.9300
# 📚 Epoch 6/10: Train Acc=0.9960, Val Acc=0.9348
# 📚 Epoch 7/10: Train Acc=0.9974, Val Acc=0.9340
# 📚 Epoch 8/10: Train Acc=0.9954, Val Acc=0.9316
# 📚 Epoch 9/10: Train Acc=0.9976, Val Acc=0.9372
# 📚 Epoch 10/10: Train Acc=0.9976, Val Acc=0.9300
#    🔁 Fold 2/5
# 📚 Epoch 1/10: Train Acc=0.5596, Val Acc=0.8504
# 📚 Epoch 2/10: Train Acc=0.9079, Val Acc=0.8930
# 📚 Epoch 3/10: Train Acc=0.9674, Val Acc=0.9099
# 📚 Epoch 4/10: Train Acc=0.9853, Val Acc=0.9220
# 📚 Epoch 5/10: Train Acc=0.9934, Val Acc=0.9212
# 📚 Epoch 6/10: Train Acc=0.9976, Val Acc=0.9268
# 📚 Epoch 7/10: Train Acc=0.9970, Val Acc=0.9268
# 📚 Epoch 8/10: Train Acc=0.9974, Val Acc=0.9212
# 📚 Epoch 9/10: Train Acc=0.9974, Val Acc=0.9276
# 📚 Epoch 10/10: Train Acc=0.9978, Val Acc=0.9195
#    🔁 Fold 3/5
# 📚 Epoch 1/10: Train Acc=0.5073, Val Acc=0.8423
# 📚 Epoch 2/10: Train Acc=0.9046, Val Acc=0.9187
# 📚 Epoch 3/10: Train Acc=0.9672, Val Acc=0.9284
# 📚 Epoch 4/10: Train Acc=0.9877, Val Acc=0.9300
# 📚 Epoch 5/10: Train Acc=0.9922, Val Acc=0.9356
# 📚 Epoch 6/10: Train Acc=0.9976, Val Acc=0.9397
# 📚 Epoch 7/10: Train Acc=0.9980, Val Acc=0.9364
# 📚 Epoch 8/10: Train Acc=0.9958, Val Acc=0.9212
# 📚 Epoch 9/10: Train Acc=0.9978, Val Acc=0.9340
# 📚 Epoch 10/10: Train Acc=0.9966, Val Acc=0.9389
#    🔁 Fold 4/5
# 📚 Epoch 1/10: Train Acc=0.5617, Val Acc=0.8463
# 📚 Epoch 2/10: Train Acc=0.9048, Val Acc=0.9010
# 📚 Epoch 3/10: Train Acc=0.9674, Val Acc=0.9195
# 📚 Epoch 4/10: Train Acc=0.9835, Val Acc=0.9204
# 📚 Epoch 5/10: Train Acc=0.9930, Val Acc=0.9292
# 📚 Epoch 6/10: Train Acc=0.9962, Val Acc=0.9292
# 📚 Epoch 7/10: Train Acc=0.9960, Val Acc=0.9300
# 📚 Epoch 8/10: Train Acc=0.9978, Val Acc=0.9364
# 📚 Epoch 9/10: Train Acc=0.9972, Val Acc=0.9316
# 📚 Epoch 10/10: Train Acc=0.9990, Val Acc=0.9348
#    🔁 Fold 5/5
# 📚 Epoch 1/10: Train Acc=0.5654, Val Acc=0.8486
# 📚 Epoch 2/10: Train Acc=0.9083, Val Acc=0.9211
# 📚 Epoch 3/10: Train Acc=0.9700, Val Acc=0.9316
# 📚 Epoch 4/10: Train Acc=0.9875, Val Acc=0.9428
# 📚 Epoch 5/10: Train Acc=0.9944, Val Acc=0.9404
# 📚 Epoch 6/10: Train Acc=0.9960, Val Acc=0.9404
# 📚 Epoch 7/10: Train Acc=0.9962, Val Acc=0.9404
# 📚 Epoch 8/10: Train Acc=0.9966, Val Acc=0.9388
# 📚 Epoch 9/10: Train Acc=0.9974, Val Acc=0.9388
# 📚 Epoch 10/10: Train Acc=0.9980, Val Acc=0.9243
# ✅ LR=5e-05, BS=64 → Avg Val Acc: 0.9295
#
# 🔧 Tuning for LR=1e-05, Batch Size=32
#    🔁 Fold 1/5
# 📚 Epoch 1/10: Train Acc=0.3062, Val Acc=0.6420
# 📚 Epoch 2/10: Train Acc=0.7477, Val Acc=0.8351
# 📚 Epoch 3/10: Train Acc=0.8709, Val Acc=0.8882
# 📚 Epoch 4/10: Train Acc=0.9159, Val Acc=0.9043
# 📚 Epoch 5/10: Train Acc=0.9523, Val Acc=0.9139
# 📚 Epoch 6/10: Train Acc=0.9630, Val Acc=0.9228
# 📚 Epoch 7/10: Train Acc=0.9775, Val Acc=0.9292
# 📚 Epoch 8/10: Train Acc=0.9835, Val Acc=0.9276
# 📚 Epoch 9/10: Train Acc=0.9867, Val Acc=0.9316
# 📚 Epoch 10/10: Train Acc=0.9875, Val Acc=0.9324
#    🔁 Fold 2/5
# 📚 Epoch 1/10: Train Acc=0.2953, Val Acc=0.5897
# 📚 Epoch 2/10: Train Acc=0.7228, Val Acc=0.8254
# 📚 Epoch 3/10: Train Acc=0.8696, Val Acc=0.8681
# 📚 Epoch 4/10: Train Acc=0.9175, Val Acc=0.8882
# 📚 Epoch 5/10: Train Acc=0.9493, Val Acc=0.8994
# 📚 Epoch 6/10: Train Acc=0.9650, Val Acc=0.8978
# 📚 Epoch 7/10: Train Acc=0.9720, Val Acc=0.9099
# 📚 Epoch 8/10: Train Acc=0.9831, Val Acc=0.9067
# 📚 Epoch 9/10: Train Acc=0.9877, Val Acc=0.9115
# 📚 Epoch 10/10: Train Acc=0.9883, Val Acc=0.9187
#    🔁 Fold 3/5
# 📚 Epoch 1/10: Train Acc=0.3114, Val Acc=0.6573
# 📚 Epoch 2/10: Train Acc=0.7495, Val Acc=0.8439
# 📚 Epoch 3/10: Train Acc=0.8729, Val Acc=0.8898
# 📚 Epoch 4/10: Train Acc=0.9161, Val Acc=0.9091
# 📚 Epoch 5/10: Train Acc=0.9449, Val Acc=0.9139
# 📚 Epoch 6/10: Train Acc=0.9634, Val Acc=0.9228
# 📚 Epoch 7/10: Train Acc=0.9732, Val Acc=0.9308
# 📚 Epoch 8/10: Train Acc=0.9819, Val Acc=0.9316
# 📚 Epoch 9/10: Train Acc=0.9843, Val Acc=0.9332
# 📚 Epoch 10/10: Train Acc=0.9891, Val Acc=0.9356
#    🔁 Fold 4/5
# 📚 Epoch 1/10: Train Acc=0.3098, Val Acc=0.5849
# 📚 Epoch 2/10: Train Acc=0.7333, Val Acc=0.8286
# 📚 Epoch 3/10: Train Acc=0.8644, Val Acc=0.8705
# 📚 Epoch 4/10: Train Acc=0.9151, Val Acc=0.8994
# 📚 Epoch 5/10: Train Acc=0.9447, Val Acc=0.9043
# 📚 Epoch 6/10: Train Acc=0.9628, Val Acc=0.9147
# 📚 Epoch 7/10: Train Acc=0.9736, Val Acc=0.9195
# 📚 Epoch 8/10: Train Acc=0.9825, Val Acc=0.9252
# 📚 Epoch 9/10: Train Acc=0.9867, Val Acc=0.9244
# 📚 Epoch 10/10: Train Acc=0.9897, Val Acc=0.9300
#    🔁 Fold 5/5
# 📚 Epoch 1/10: Train Acc=0.3065, Val Acc=0.6514
# 📚 Epoch 2/10: Train Acc=0.7466, Val Acc=0.8519
# 📚 Epoch 3/10: Train Acc=0.8691, Val Acc=0.8961
# 📚 Epoch 4/10: Train Acc=0.9220, Val Acc=0.9050
# 📚 Epoch 5/10: Train Acc=0.9473, Val Acc=0.9147
# 📚 Epoch 6/10: Train Acc=0.9690, Val Acc=0.9179
# 📚 Epoch 7/10: Train Acc=0.9757, Val Acc=0.9243
# 📚 Epoch 8/10: Train Acc=0.9831, Val Acc=0.9283
# 📚 Epoch 9/10: Train Acc=0.9885, Val Acc=0.9267
# 📚 Epoch 10/10: Train Acc=0.9889, Val Acc=0.9235
# ✅ LR=1e-05, BS=32 → Avg Val Acc: 0.9281
#
# 🔧 Tuning for LR=1e-05, Batch Size=64
#    🔁 Fold 1/5
# 📚 Epoch 1/10: Train Acc=0.1975, Val Acc=0.3829
# 📚 Epoch 2/10: Train Acc=0.5663, Val Acc=0.7353
# 📚 Epoch 3/10: Train Acc=0.7733, Val Acc=0.8407
# 📚 Epoch 4/10: Train Acc=0.8686, Val Acc=0.8769
# 📚 Epoch 5/10: Train Acc=0.9069, Val Acc=0.9019
# 📚 Epoch 6/10: Train Acc=0.9356, Val Acc=0.9059
# 📚 Epoch 7/10: Train Acc=0.9521, Val Acc=0.9123
# 📚 Epoch 8/10: Train Acc=0.9618, Val Acc=0.9179
# 📚 Epoch 9/10: Train Acc=0.9706, Val Acc=0.9228
# 📚 Epoch 10/10: Train Acc=0.9793, Val Acc=0.9276
#    🔁 Fold 2/5
# 📚 Epoch 1/10: Train Acc=0.2016, Val Acc=0.3966
# 📚 Epoch 2/10: Train Acc=0.5775, Val Acc=0.7409
# 📚 Epoch 3/10: Train Acc=0.8053, Val Acc=0.8423
# 📚 Epoch 4/10: Train Acc=0.8709, Val Acc=0.8713
# 📚 Epoch 5/10: Train Acc=0.9073, Val Acc=0.8825
# 📚 Epoch 6/10: Train Acc=0.9320, Val Acc=0.8994
# 📚 Epoch 7/10: Train Acc=0.9501, Val Acc=0.9083
# 📚 Epoch 8/10: Train Acc=0.9658, Val Acc=0.9091
# 📚 Epoch 9/10: Train Acc=0.9769, Val Acc=0.9155
# 📚 Epoch 10/10: Train Acc=0.9761, Val Acc=0.9155
#    🔁 Fold 3/5
# 📚 Epoch 1/10: Train Acc=0.1875, Val Acc=0.3829
# 📚 Epoch 2/10: Train Acc=0.5548, Val Acc=0.7522
# 📚 Epoch 3/10: Train Acc=0.7920, Val Acc=0.8504
# 📚 Epoch 4/10: Train Acc=0.8692, Val Acc=0.8866
# 📚 Epoch 5/10: Train Acc=0.9103, Val Acc=0.9059
# 📚 Epoch 6/10: Train Acc=0.9390, Val Acc=0.9195
# 📚 Epoch 7/10: Train Acc=0.9547, Val Acc=0.9228
# 📚 Epoch 8/10: Train Acc=0.9696, Val Acc=0.9220
# 📚 Epoch 9/10: Train Acc=0.9755, Val Acc=0.9252
# 📚 Epoch 10/10: Train Acc=0.9785, Val Acc=0.9332
#    🔁 Fold 4/5
# 📚 Epoch 1/10: Train Acc=0.2173, Val Acc=0.3982
# 📚 Epoch 2/10: Train Acc=0.5536, Val Acc=0.7184
# 📚 Epoch 3/10: Train Acc=0.7801, Val Acc=0.8351
# 📚 Epoch 4/10: Train Acc=0.8642, Val Acc=0.8761
# 📚 Epoch 5/10: Train Acc=0.9085, Val Acc=0.8882
# 📚 Epoch 6/10: Train Acc=0.9326, Val Acc=0.8962
# 📚 Epoch 7/10: Train Acc=0.9527, Val Acc=0.9115
# 📚 Epoch 8/10: Train Acc=0.9640, Val Acc=0.9123
# 📚 Epoch 9/10: Train Acc=0.9712, Val Acc=0.9204
# 📚 Epoch 10/10: Train Acc=0.9783, Val Acc=0.9195
#    🔁 Fold 5/5
# 📚 Epoch 1/10: Train Acc=0.2130, Val Acc=0.4275
# 📚 Epoch 2/10: Train Acc=0.5720, Val Acc=0.7359
# 📚 Epoch 3/10: Train Acc=0.7862, Val Acc=0.8470
# 📚 Epoch 4/10: Train Acc=0.8644, Val Acc=0.8849
# 📚 Epoch 5/10: Train Acc=0.9023, Val Acc=0.8929
# 📚 Epoch 6/10: Train Acc=0.9292, Val Acc=0.9106
# 📚 Epoch 7/10: Train Acc=0.9485, Val Acc=0.9187
# 📚 Epoch 8/10: Train Acc=0.9616, Val Acc=0.9195
# 📚 Epoch 9/10: Train Acc=0.9728, Val Acc=0.9259
# 📚 Epoch 10/10: Train Acc=0.9767, Val Acc=0.9259
# ✅ LR=1e-05, BS=64 → Avg Val Acc: 0.9244
#
# 🏆 Best Config → LR=5e-05, BS=32 with Val Acc=0.9295

# %%
import os
import torch
import timm
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, ConcatDataset
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score

# ==== Paths ====
data_dir = r"C:\Users\STUDENT\Downloads\FishDataset_Split"
train_dir = os.path.join(data_dir, "train")
val_dir = os.path.join(data_dir, "val")
test_dir = os.path.join(data_dir, "test")

# ==== Device ====
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"🔧 Using device: {device}")

# ==== Transforms ====
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(0.2, 0.2, 0.3),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# ==== Load and Combine Train + Val ====
train_dataset = datasets.ImageFolder(train_dir, transform=train_transform)
val_dataset = datasets.ImageFolder(val_dir, transform=train_transform)
full_train_dataset = ConcatDataset([train_dataset, val_dataset])

test_dataset = datasets.ImageFolder(test_dir, transform=test_transform)
class_names = train_dataset.classes
num_classes = len(class_names)

train_loader = DataLoader(full_train_dataset, batch_size=32, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# ==== Model ====
model = timm.create_model('swin_tiny_patch4_window7_224', pretrained=True, num_classes=num_classes)
model = model.to(device)

# ==== Training Setup ====
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=5e-05)
epochs = 15

# ==== Training Loop ====
print("🚀 Training final Swin-Tiny model on full training set...")
for epoch in range(epochs):
    model.train()
    running_loss, correct, total = 0.0, 0, 0

    for inputs, labels in DataLoader(full_train_dataset, batch_size=32, shuffle=True, num_workers=2):
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        correct += (outputs.argmax(1) == labels).sum().item()
        total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_acc = correct / total
    print(f"📘 Epoch {epoch+1}: Loss = {epoch_loss:.4f}, Acc = {epoch_acc*100:.2f}%")

# ==== Save Final Model ====
torch.save(model.state_dict(), "final_swin_model.pth")
print("✅ Final Swin-Tiny model saved as 'final_swin_model.pth'")

# ==== Evaluation on Test Set ====
print("\n🧪 Evaluating on Test Set...")
model.eval()
y_true, y_pred = [], []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        preds = outputs.argmax(1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# ==== Accuracy ====
test_accuracy = 100 * np.mean(np.array(y_true) == np.array(y_pred))
print(f"\n✅ Final Test Accuracy: {test_accuracy:.2f}%")

# ==== Classification Report ====
print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=3))

# ==== Precision, Recall, F1 Scores ====
precision_macro = precision_score(y_true, y_pred, average='macro')
recall_macro = recall_score(y_true, y_pred, average='macro')
f1_macro = f1_score(y_true, y_pred, average='macro')

precision_weighted = precision_score(y_true, y_pred, average='weighted')
recall_weighted = recall_score(y_true, y_pred, average='weighted')
f1_weighted = f1_score(y_true, y_pred, average='weighted')

print("\n📈 Performance Summary:")
print(f"🔹 Macro Precision : {precision_macro:.4f}")
print(f"🔹 Macro Recall    : {recall_macro:.4f}")
print(f"🔹 Macro F1 Score  : {f1_macro:.4f}")
print(f"🔸 Weighted Precision : {precision_weighted:.4f}")
print(f"🔸 Weighted Recall    : {recall_weighted:.4f}")
print(f"🔸 Weighted F1 Score  : {f1_weighted:.4f}")
# Out:
# 🔧 Using device: cuda
# 🚀 Training final Swin-Tiny model on full training set...
# 📘 Epoch 1: Loss = 1.1326, Acc = 69.95%
# 📘 Epoch 2: Loss = 0.2776, Acc = 92.35%
# 📘 Epoch 3: Loss = 0.1480, Acc = 96.20%
# 📘 Epoch 4: Loss = 0.0925, Acc = 97.86%
# 📘 Epoch 5: Loss = 0.0674, Acc = 98.51%
# 📘 Epoch 6: Loss = 0.0501, Acc = 98.99%
# 📘 Epoch 7: Loss = 0.0542, Acc = 98.59%
# 📘 Epoch 8: Loss = 0.0441, Acc = 98.91%
# 📘 Epoch 9: Loss = 0.0425, Acc = 98.82%
# 📘 Epoch 10: Loss = 0.0501, Acc = 98.57%
# 📘 Epoch 11: Loss = 0.0342, Acc = 99.26%
# 📘 Epoch 12: Loss = 0.0329, Acc = 99.20%
# 📘 Epoch 13: Loss = 0.0341, Acc = 99.11%
# 📘 Epoch 14: Loss = 0.0319, Acc = 99.12%
# 📘 Epoch 15: Loss = 0.0325, Acc = 99.20%
# ✅ Final Swin-Tiny model saved as 'final_swin_model.pth'
#
# 🧪 Evaluating on Test Set...
#
# ✅ Final Test Accuracy: 94.22%
#
# 📊 Classification Report:
#                        precision    recall  f1-score   support
#
#                Bangus      0.955     0.778     0.857        27
#         Big Head Carp      0.886     0.969     0.925        32
#    Black Spotted Barb      1.000     0.968     0.984        31
#               Catfish      0.941     0.960     0.950        50
#        Climbing Perch      1.000     0.792     0.884        24
#  Fourfinger Threadfin      0.853     0.967     0.906        30
#        Freshwater Eel      0.930     0.952     0.941        42
#        Glass Perchlet      0.919     0.934     0.927        61
#                  Goby      0.954     0.892     0.922        93
#             Gold Fish      1.000     0.941     0.970        34
#               Gourami      0.980     1.000     0.990        48
#            Grass Carp      0.979     0.974     0.976       190
#  Green Spotted Puffer      1.000     1.000     1.000        18
#           Indian Carp      1.000     0.951     0.975        41
#   Indo-Pacific Tarpon      0.963     0.897     0.929        29
#         Jaguar Gapote      0.972     0.972     0.972        36
#          Janitor Fish      0.882     1.000     0.938        45
#             Knifefish      1.000     0.980     0.990        50
# Long-Snouted Pipefish      0.975     0.975     0.975        40
#         Mosquito Fish      0.902     0.974     0.937        38
#               Mudfish      0.774     0.828     0.800        29
#                Mullet      0.862     0.893     0.877        28
#             Pangasius      1.000     0.867     0.929        30
#                 Perch      0.978     0.978     0.978        46
#             Scat Fish      1.000     0.955     0.977        22
#           Silver Barb      0.922     0.940     0.931        50
#           Silver Carp      1.000     1.000     1.000        38
#          Silver Perch      0.909     0.930     0.920        43
#             Snakehead      0.865     0.865     0.865        37
#            Tenpounder      0.778     0.897     0.833        39
#               Tilapia      0.978     0.957     0.967        46
#
#              accuracy                          0.942      1367
#             macro avg      0.941     0.935     0.936      1367
#          weighted avg      0.945     0.942     0.942      1367
#
#
# 📈 Performance Summary:
# 🔹 Macro Precision : 0.9405
# 🔹 Macro Recall    : 0.9350
# 🔹 Macro F1 Score  : 0.9362
# 🔸 Weighted Precision : 0.9449
# 🔸 Weighted Recall    : 0.9422
# 🔸 Weighted F1 Score  : 0.9424

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# === Generate confusion matrix ===
cm = confusion_matrix(y_true, y_pred)
num_classes = cm.shape[0]

# === Plot ===
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=True,
            xticklabels=np.arange(num_classes),
            yticklabels=np.arange(num_classes),
            linewidths=0, linecolor='white', square=True)

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Swin_tiny)")
plt.tight_layout()
plt.show()
